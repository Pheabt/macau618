# %%
import requests
import json
import pprint
import pandas as pd
import pprint

import urllib
import math

# %%
key='d3b9d9e62888e1c449294703009cc1b2' 
def getlocation(address):
    url='https://restapi.amap.com/v3/geocode/geo'
    params = {
        'key':key,
        'address':address
    }
    res = requests.get(url, params)
    json_data = json.loads(res.text)
    return json_data

# %%
inpath = r'1.xlsx'
outpath = r'12.xlsx'

df = pd.read_excel(inpath)
df['lng'] = 'collng'
df['lat'] = 'collat'

for i in df.values:
    ind = i[0]
    b = i[1]
    print(b)
    data = getlocation('澳门'+b)

    if 'geocodes' in data:
        i[2] = data['geocodes'][0]['location']
    else:
        continue

    df['lng'][ind] = float(i[2].split(",")[0])
    df['lat'][ind] = float(i[2].split(",")[1])

df.to_excel(outpath)
# Out:
# 爹利仙拿姑娘街永珍大廈
# C:\Users\KK\AppData\Local\Temp\ipykernel_21212\1608722638.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['lng'][ind] = float(i[2].split(",")[0])
# C:\Users\KK\AppData\Local\Temp\ipykernel_21212\1608722638.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['lat'][ind] = float(i[2].split(",")[1])
# 山顶医院
# 路環金峰南岸 12座
# 氹仔碼頭輕軌站
# 澳门东亚运动会体育馆
# 路環金峰南岸 12 座
# 石排灣核酸站
# 路環金峰南岸 12 座
# 澳门东亚运动会体育馆
# 祐漢新村第一街 61 號興隆樓
# 倫敦人
# 祐漢新村第一街 61 號興隆樓
# 白鴿巢國光大廈
# 新苗超級市場(祐漢新邨店)
# 澳门工人體育館
# 澳门东亚运动会体育馆
# 黑沙環第七街錦繡花園
# 中葡職業技術學校體育館
# 祐漢新苗超級巿場
# 祐漢來來超級巿場
# 黑沙環第七街錦繡花園
# 中葡職業技術學校體育館
# 祐漢新苗超級巿場
# 祐漢來來超級巿場
# 澳門三巴仔街 9 號德昌大廈
# 美麗街 21 號怡美大廈
# 威尼斯人
# 四季酒店 DFS
# 澳門三巴仔街 9 號德昌大廈
# 美麗街 21 號怡美大廈
# 威尼斯人
# 四季酒店 DFS
# 澳門三巴仔街 9 號德昌大廈
# 澳门东亚运动会体育馆
# 趙家巷 12 號信鈴軒
# 利瑪竇中學
# 澳门东亚运动会体育馆
# 趙家巷信鈴軒
# 澳门东亚运动会体育馆
# 林茂海邊街 358 號朗濠坊
# 澳门东亚运动会体育馆
# 黑沙環新街 297 號金海山花園
# 中葡職業技術學校站
# 黑沙環新街 297 號金海山花園
# 勞動節街 36 號裕華大廈（第十二座）
# 裕華利豐超巿
# 永利皇宮
# 勞動節街 36 號裕華大廈（第十二座）
# 永利皇宮
